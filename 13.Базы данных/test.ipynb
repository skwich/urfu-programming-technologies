# %%
import pandas as pd
import sqlite3


database_name = "dbname.db"
csv_file = "vacancies.csv"
table_name = "tableName"

# %%
df = pd.read_csv(csv_file)

# %%
df["salary"] = df[["salary_from", "salary_to"]].mean(axis=1)
df
# Out:
#                                                  name  \
# 0                   Руководитель группы разработчиков
# 1                     Ведущий аналитик баз данных SQL
# 2                         Электромеханик производства
# 3                    Менеджер по ведению справочников
# 4                             Аналитик (Контур.Фокус)
# ..                                                ...
# 341                                     Архитектор 1С
# 342  Специалист по ремонту и обслуживанию спецтехники
# 343                         Механик в сервисный центр
# 344                                  Специалист по ОТ
# 345                            Оператор станков с ЧПУ
#
#                                            description  \
# 0    <p>Наш клиент, один из ведущих банков страны, ...
# 1    <p>Крупнейший исследовательский холдинг, специ...
# 2    <p><strong>Группа компаний «МИАКОМ»</strong> о...
# 3    <p><strong>О компании:</strong></p> <p><strong...
# 4    <p>Контур<strong> </strong>— ведущий разработч...
# ..                                                 ...
# 341  <p><strong>АО «РЭС» </strong>занимает доминиру...
# 342  <p>Федеральная Компания <strong>БИГЦЕНТР</stro...
# 343  <strong>Обязанности:</strong> <ul> <li>Ремонт ...
# 344  <strong>Обязанности:</strong> <ul> <li>Контрол...
# 345  <strong>Обязанности:</strong> <ul> <li>Обслужи...
#
#                                             key_skills experience_id  premium  \
# 0    Работа в команде\nОрганизаторские навыки\nУпра...  between3And6    False
# 1                                                  NaN     moreThan6    False
# 2    Умение работать в команде\nТехническая эксплуа...  between1And3    False
# 3                                                  NaN  between1And3    False
# 4    Системное мышление\nАналитические исследования...  between3And6    False
# ..                                                 ...           ...      ...
# 341                                                NaN  between3And6    False
# 342  Выездное обслуживание\nРабота в команде\nТехни...  between1And3    False
# 343  Работа в команде\nОтветственность\nпунктуально...  noExperience    False
# 344                                                NaN  between1And3    False
# 345  Информационные технологии\nАвтоматизированное ...  between1And3    False
#
#                                          employer_name  salary_from  \
# 0                                              Selecty          NaN
# 1                                            М-Холдинг          NaN
# 2                                               МИАКОМ      50000.0
# 3                                             АйДи-360          NaN
# 4                                               Контур          NaN
# ..                                                 ...          ...
# 341  Акционерное общество «Региональные электрическ...          NaN
# 342                                           БИГЦЕНТР      90000.0
# 343                                         Арсенал-БТ      45000.0
# 344  ФИЛИАЛ ООО КИТАЙСКАЯ НАЦИОНАЛЬНАЯ ХИМИКО-ИНЖЕН...          NaN
# 345                    Сервисный центр СибЭнергоРесурс      80000.0
#
#      salary_to salary_gross salary_currency                       area_name  \
# 0          NaN          NaN             NaN                     Новосибирск
# 1          NaN          NaN             NaN                          Москва
# 2          NaN        False             RUR  Рощино (Ленинградская область)
# 3      90000.0        False             RUR                          Москва
# 4          NaN          NaN             NaN                    Екатеринбург
# ..         ...          ...             ...                             ...
# 341        NaN          NaN             NaN                     Новосибирск
# 342   120000.0        False             RUR                      Домодедово
# 343    55000.0        False             RUR                     Новосибирск
# 344        NaN          NaN             NaN                            Омск
# 345   100000.0         True             RUR               Ленинск-Кузнецкий
#
#                  published_at    salary
# 0    2022-07-05T18:19:30+0300       NaN
# 1    2022-07-05T18:20:15+0300       NaN
# 2    2022-07-15T09:56:52+0300   50000.0
# 3    2022-07-17T18:21:27+0300   90000.0
# 4    2022-07-05T18:21:28+0300       NaN
# ..                        ...       ...
# 341  2022-07-06T05:12:48+0300       NaN
# 342  2022-07-18T05:14:34+0300  105000.0
# 343  2022-07-18T05:14:45+0300   50000.0
# 344  2022-07-06T05:14:46+0300       NaN
# 345  2022-07-18T06:47:24+0300   90000.0
#
# [346 rows x 13 columns]
